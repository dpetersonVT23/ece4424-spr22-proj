# %% [markdown]
# ---
# # **License Plate Recognition**
# ##**David Peterson - ECE 4424 - Spring 2022 Project - AMLPR**
# ---

# %% [markdown]
# ### **Data Loading and Pre-Processing**###
# 1.   Mount Google Drive
# 2.   Load original license plate image dataset - number labels
# 3.   Modify original license plate image dataset structure for YOLOv3 application
#
# **Dataset Modification Details:**
#
# - Dataset Train-Test Split: 80% Train | 20% Train
#
# - File Structure in Recognition Directory:
# > lp_num_img_data (original)
# > recognition_data (modified)
#
# - Original format of dataset:
#   - Separate train and test text files with image file paths and labels for each image
# > images/imageX.jpg
# > imageX label
# > ...
#
# - Modified format of dataset:
#   - Separate train and test text files with only image file paths
#   - Separate labels directory with text files for individual image labels
#
#   - File Structure in recognition_data directory:
# > recognition_train.txt
# > recognition_test.txt
# > images
# > labels

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# append the directory to your python path using sys
import sys
import os
prefix = '/content/drive/MyDrive/'

# customized path to detection directory
cust_path_detection = 'ECE4424/Project/detection'
sys_path_detection = prefix + cust_path_detection
sys.path.append(sys_path_detection)

# customized path to recognition directory
cust_path_recognition = 'ECE4424/Project/recognition'
sys_path_recognition = prefix + cust_path_recognition
sys.path.append(sys_path_recognition)

print("Path to detection directory: {}".format(sys_path_detection))
print("Path to recognition directory: {}".format(sys_path_recognition))
# Out:
# Path to detection directory: /content/drive/MyDrive/ECE4424/Project/detection
# Path to recognition directory: /content/drive/MyDrive/ECE4424/Project/recognition

# %%
# import dependencies
import re

# initialize path constants
LP_NUM_IMG_DATA_DIR_PATH = sys_path_recognition + "/lp_num_img_data"  # path to original dataset directory
TRAIN_DATA_FILE_PATH = LP_NUM_IMG_DATA_DIR_PATH + "/train_data.txt"   # path to train data file
TEST_DATA_FILE_PATH = LP_NUM_IMG_DATA_DIR_PATH + "/test_data.txt"     # path to test data file

# load train and test datasets
train_data_file = open(TRAIN_DATA_FILE_PATH, "r")  # open train data file
test_data_file = open(TEST_DATA_FILE_PATH, "r")    # open test data file

# separate train data into file names and labels lists
train_data_fps = []                                                   # initialize list for train data image file paths
train_data_lbls = []                                                  # initialize list for train data labels
for idx, line in enumerate(train_data_file):                          # for each line in the train data file
    if not idx % 2:                                                       # if line index is even
        train_data_fps.append(line.strip()[1:])                               # append image file name to train data image file names list
    else:                                                                 # else
        train_data_lbls.append(line.strip())                                  # append label to train data label list as a string

# organize train data into file names:labels dictionary
train_data = {}
for idx in range(len(train_data_fps)):                                # for each train image
    train_data[train_data_fps[idx]] = train_data_lbls[idx]                # insert file name-labels key-value pair

# separate test data into file names and labels lists
test_data_fps = []                                                    # initialize list for test data image file paths
test_data_lbls = []                                                   # initialize list for test data labels
for idx, line in enumerate(test_data_file):                           # for each line in the test data file
    if not idx % 2:                                                       # if line index is even
        test_data_fps.append(line.strip()[1:])                                # append image file name to test data image file names list
    else:                                                                 # else
        test_data_lbls.append(line.strip())                                   # append label to test data label list as a string

# organize test data into file names:labels dictionary
test_data = {}
for idx in range(len(test_data_fps)):                                 # for each test image
    test_data[test_data_fps[idx]] = test_data_lbls[idx]                   # insert file name-labels key-value pair

all_data_fps = train_data_fps + test_data_fps       # initialize list to store all data file paths

all_data_fns = []                                   # initialize list to store all data file names
for fp in all_data_fps:                             # for each image file path
    all_data_fns.append(re.split("/|\.", fp)[2])        # obtain file name from current input image file path


print("Train Data: {}".format(train_data))
print("Amount of Train Data: {}".format(len(train_data)))
print("Test Data: {}".format(test_data))
print("Amount of Test Data: {}".format(len(test_data)))
print("All Data File Paths: {}".format(all_data_fps))
print("All Data File Names: {}".format(all_data_fns))
print("[STATUS] Original data loaded successfully.")
# Out:
# Train Data: {'/images/cars4_052.jpg': '3UDX841', '/images/cars2_021.jpg': '3MYH761', '/images/cars4_074.jpg': '5HZW063', '/images/cars4_010.jpg': '5CJB364', '/images/cars3_026.jpg': '4GQG231', '/images/cars4_085.jpg': '2PXR727', '/images/cars063.jpg': '5DHU058', '/images/cars4_061.jpg': '4BRM434', '/images/cars4_080.jpg': '4CBM944', '/images/cars4_128.jpg': '5JJV943', '/images/cars4_127.jpg': '5BSM366', '/images/cars4_065.jpg': '3SFW623', '/images/cars4_037.jpg': '4LXC614', '/images/cars060.jpg': '5HCV316', '/images/cars4_105.jpg': '5GEC237', '/images/cars4_116.jpg': '3UUJ586', '/images/cars4_124.jpg': '5GAM144', '/images/cars2_052.jpg': '4UCF349', '/images/cars4_060.jpg': '5ETA743', '/images/cars4_005.jpg': '3UXY336', '/images/cars056.jpg': '4ZTJ876', '/images/cars4_020.jpg': 'MADZBMR', '/images/cars2_035.jpg': '2VLR763', '/images/cars2_032.jpg': '4VAH764', '/images/cars4_055.jpg': '3UTA977', '/images/cars2_068.jpg': '4TIX783', '/images/cars2_042.jpg': '4VLX070', '/images/cars4_026.jpg': '6J01992', '/images/cars2_043.jpg': '3VDM690', '/images/cars2_073.jpg': '5JBR554', '/images/cars4_091.jpg': '4LMC535', '/images/cars4_096.jpg': '5EMR875', '/images/cars3_017.jpg': '4EZH622', '/images/cars2_066.jpg': '4MBS696', '/images/cars2_049.jpg': '5FZH911', '/images/cars4_108.jpg': '3DGL956', '/images/cars4_099.jpg': '3LVH137', '/images/cars3_024.jpg': '4HGT934', '/images/cars4_081.jpg': '5EFR764', '/images/cars2_017.jpg': '3KGD519', '/images/cars027.jpg': '5AZJ257', '/images/cars2_014.jpg': '4YNT983', '/images/cars4_114.jpg': '4JKA394', '/images/cars4_014.jpg': '4DRP153', '/images/cars2_007.jpg': '4GJB914', '/images/cars026.jpg': '4YTD483', '/images/cars4_117.jpg': '4JRV393', '/images/cars3_020.jpg': '5CQU569', '/images/cars4_107.jpg': '3LUK250', '/images/cars3_019.jpg': '4YUF560', '/images/cars061.jpg': '6K75488', '/images/cars4_092.jpg': '4RHM244', '/images/cars066.jpg': '5JUU305', '/images/cars2_061.jpg': '3HMC645', '/images/cars4_054.jpg': '4WOU744', '/images/cars2_005.jpg': '2ZMF731', '/images/cars4_033.jpg': '4RZD675', '/images/cars3_011.jpg': '4AYK317', '/images/cars036.jpg': '5AOG200', '/images/cars4_073.jpg': '4DSP764', '/images/cars070.jpg': '4KRH440', '/images/cars2_045.jpg': 'ONEOFME', '/images/cars4_015.jpg': '4ZWZ399', '/images/cars4_008.jpg': '4BMZ563', '/images/cars2_044.jpg': '6M28575', '/images/cars4_083.jpg': '1408S', '/images/cars032.jpg': '5FVL554', '/images/cars065.jpg': '4KYR003', '/images/cars040.jpg': '6F55687', '/images/cars4_069.jpg': '5DXZ250', '/images/cars3_013.jpg': '4YZU576', '/images/cars4_109.jpg': 'MARETA', '/images/cars2_025.jpg': '4YNE038', '/images/cars4_007.jpg': '4ROW485', '/images/cars4_129.jpg': '4FVV176', '/images/cars2_010.jpg': '5AFD170', '/images/cars4_030.jpg': '7J15194', '/images/cars4_097.jpg': '4YHY530', '/images/cars3_007.jpg': '5DJZ952', '/images/cars4_019.jpg': '5JMZ542', '/images/cars4_048.jpg': '4RIM152', '/images/cars4_113.jpg': '4SFK926', '/images/cars2_034.jpg': '5N30048', '/images/cars4_039.jpg': '2TVZ312', '/images/cars3_031.jpg': '5BPJ707', '/images/cars4_126.jpg': '5GEF645', '/images/cars4_131.jpg': '4GTA922', '/images/cars4_110.jpg': '4GNE041', '/images/cars3_027.jpg': '4RXJ811', '/images/cars3_021.jpg': '5EQF286', '/images/cars4_056.jpg': '5BQE919', '/images/cars3_010.jpg': '2XAX069', '/images/cars3_009.jpg': '4UPV426', '/images/cars4_125.jpg': '4TZB662', '/images/cars4_040.jpg': '4FWH626', '/images/cars052.jpg': '5EDP688', '/images/cars2_012.jpg': '4UET042', '/images/cars4_122.jpg': '4JPY855', '/images/cars2_056.jpg': '4WKZ117', '/images/cars045.jpg': '4RFV131', '/images/cars3_008.jpg': '4LZW133', '/images/cars4_123.jpg': 'JSR113', '/images/cars2_051.jpg': '4YKX864', '/images/cars4_088.jpg': '4COV126', '/images/cars058.jpg': '4ZNS935', '/images/cars2_008.jpg': '3UMH807', '/images/cars2_002.jpg': '4URR806', '/images/cars2_016.jpg': '3LRH261', '/images/cars4_031.jpg': '3LUD179', '/images/cars057.jpg': '5GGG842', '/images/cars4_034.jpg': '5CEV521', '/images/cars051.jpg': '5GR ...
# Amount of Train Data: 196
# Test Data: {'/images/cars4_046.jpg': '4DSP764', '/images/cars4_086.jpg': '3RMX731', '/images/cars3_006.jpg': '4YUJ904', '/images/cars4_087.jpg': '4GNU890', '/images/cars4_006.jpg': '5CGP522', '/images/cars2_070.jpg': '4RYG474', '/images/cars068.jpg': '4TDS709', '/images/cars3_025.jpg': '2ZJG389', '/images/cars4_101.jpg': '2T0G518', '/images/cars029.jpg': '4TAZ530', '/images/cars2_040.jpg': '4HPV976', '/images/cars4_013.jpg': '4MXW451', '/images/cars4_022.jpg': '4PZN989', '/images/cars4_012.jpg': '5CLE992', '/images/cars033.jpg': '3VBL777', '/images/cars4_067.jpg': '3WVM533', '/images/cars4_025.jpg': 'HLPUBU', '/images/cars3_016.jpg': '4VUG504', '/images/cars2_048.jpg': '4HMS824', '/images/cars042.jpg': '4FJX296', '/images/cars4_018.jpg': '4VWL023', '/images/cars2_001.jpg': '3NBU698', '/images/cars4_075.jpg': '4AST141', '/images/cars3_012.jpg': '4WMC477', '/images/cars2_047.jpg': '3RLT669', '/images/cars4_106.jpg': '4ZPG408', '/images/cars064.jpg': '4BTP882', '/images/cars062.jpg': 'CKC3951', '/images/cars4_047.jpg': '2SQH590', '/images/cars4_071.jpg': '3GWK394', '/images/cars2_018.jpg': '4MEU123', '/images/cars4_102.jpg': 'RNM25X', '/images/cars4_084.jpg': '3VBM338', '/images/cars3_028.jpg': '4PBZ953', '/images/cars2_020.jpg': '4MTV159', '/images/cars2_071.jpg': '4FSK683', '/images/cars3_002.jpg': '4JPA838', '/images/cars4_078.jpg': '3SLS141', '/images/cars3_018.jpg': '3SAV178', '/images/cars4_118.jpg': '3TKA605', '/images/cars4_016.jpg': '018VFJ', '/images/cars2_031.jpg': '4RWR022', '/images/cars4_058.jpg': '5DES551', '/images/cars030.jpg': '4BYZ014', '/images/cars4_079.jpg': 'AHA6497', '/images/cars3_004.jpg': '3JYT812', '/images/cars4_066.jpg': '4TXY019', '/images/cars2_041.jpg': '4NIU770', '/images/cars4_004.jpg': '4EMJ817', '/images/cars4_023.jpg': '4NSJ053'}
# Amount of Test Data: 50
# All Data File Paths: ['/images/cars4_052.jpg', '/images/cars2_021.jpg', '/images/cars4_074.jpg', '/images/cars4_010.jpg', '/images/cars3_026.jpg', '/images/cars4_085.jpg', '/images/cars063.jpg', '/images/cars4_061.jpg', '/images/cars4_080.jpg', '/images/cars4_128.jpg', '/images/cars4_127.jpg', '/images/cars4_065.jpg', '/images/cars4_037.jpg', '/images/cars060.jpg', '/images/cars4_105.jpg', '/images/cars4_116.jpg', '/images/cars4_124.jpg', '/images/cars2_052.jpg', '/images/cars4_060.jpg', '/images/cars4_005.jpg', '/images/cars056.jpg', '/images/cars4_020.jpg', '/images/cars2_035.jpg', '/images/cars2_032.jpg', '/images/cars4_055.jpg', '/images/cars2_068.jpg', '/images/cars2_042.jpg', '/images/cars4_026.jpg', '/images/cars2_043.jpg', '/images/cars2_073.jpg', '/images/cars4_091.jpg', '/images/cars4_096.jpg', '/images/cars3_017.jpg', '/images/cars2_066.jpg', '/images/cars2_049.jpg', '/images/cars4_108.jpg', '/images/cars4_099.jpg', '/images/cars3_024.jpg', '/images/cars4_081.jpg', '/images/cars2_017.jpg', '/images/cars027.jpg', '/images/cars2_014.jpg', '/images/cars4_114.jpg', '/images/cars4_014.jpg', '/images/cars2_007.jpg', '/images/cars026.jpg', '/images/cars4_117.jpg', '/images/cars3_020.jpg', '/images/cars4_107.jpg', '/images/cars3_019.jpg', '/images/cars061.jpg', '/images/cars4_092.jpg', '/images/cars066.jpg', '/images/cars2_061.jpg', '/images/cars4_054.jpg', '/images/cars2_005.jpg', '/images/cars4_033.jpg', '/images/cars3_011.jpg', '/images/cars036.jpg', '/images/cars4_073.jpg', '/images/cars070.jpg', '/images/cars2_045.jpg', '/images/cars4_015.jpg', '/images/cars4_008.jpg', '/images/cars2_044.jpg', '/images/cars4_083.jpg', '/images/cars032.jpg', '/images/cars065.jpg', '/images/cars040.jpg', '/images/cars4_069.jpg', '/images/cars3_013.jpg', '/images/cars4_109.jpg', '/images/cars2_025.jpg', '/images/cars4_007.jpg', '/images/cars4_129.jpg', '/images/cars2_010.jpg', '/images/cars4_030.jpg', '/images/cars4_097.jpg', '/images/cars3_007.jpg', '/images/cars4_019.jpg', '/images/cars4_048.jpg', '/images/cars4_113.jpg', '/images/cars2_034.jpg', '/images/cars4_039.jpg', '/images/cars3_031.jpg', '/images/cars4_126.jpg', '/images/cars4_131.jpg', '/images/cars4_110.jpg', '/images/cars3_027.jpg', '/images/cars3_021.jpg', '/images/cars4_056.jpg', '/images/cars3_010.jpg', '/images/cars3_009.jpg', '/images/cars4_125.jpg', '/images/cars4_040.jpg', '/images/cars052.jpg', '/images/cars2_012.jpg', '/images/cars4_122.jpg', '/images/cars2_056.jpg', '/images/cars045.jpg', '/images/cars3_008.jpg', '/images/cars4_123.jpg', '/images/cars2_051.jpg', '/images/cars4_088.jpg', '/images/cars058.jpg', '/images/cars2_008.jpg', '/images/cars2_002.jpg', '/images/cars2_016.jpg', '/images/cars4_031.jpg', '/images/cars057.jpg', '/images/cars4_034.jpg', '/images/cars051.jpg', '/images/cars2_046.jpg', '/images/cars4_120.jpg', '/images/cars2_064.jpg', '/images/cars3_001.jpg', '/images/cars4_042.jpg', '/images/cars2_029.jpg', '/images/cars4_072.jpg', '/images/cars4_041.jpg', '/images/cars4_011.jpg', '/images/cars4_036.jpg', '/images/cars2_013.jpg', '/images/cars3_015.jpg', '/images/cars4_104.jpg', '/images/cars069.jpg', '/images/cars2_015.jpg', '/images/cars4_017.jpg', '/images/cars4_103.jpg', '/images/cars2_004.jpg', '/images/cars2_003.jpg', '/images/cars2_027.jpg', '/images/cars4_089.jpg', '/images/cars4_077.jpg', '/images/cars4_112.jpg', '/images/cars4_119.jpg', '/images/cars4_063.jpg', '/images/cars2_069.jpg', '/images/cars2_033.jpg', '/images/cars4_035.jpg', '/images/cars2_026.jpg', '/images/cars2_074.jpg', '/images/cars4_045.jpg', '/images/cars2_006.jpg', '/images/cars2_019.jpg', '/images/cars2_038.jpg', '/images/cars2_072.jpg', '/images/cars2_011.jpg', '/images/cars3_003.jpg', '/images/cars3_014.jpg', '/images/cars4_130.jpg', '/images/cars2_028.jpg', '/images/cars4_057.jpg', '/images/cars031.jpg', '/images/cars4_064.jpg', '/images/cars2_067.jpg', '/images/cars2_037.jpg', '/images/cars3_023.jpg', '/images/cars2_009.jpg', '/images/cars2_024.jpg', '/images/cars4_0 ...
# All Data File Names: ['cars4_052', 'cars2_021', 'cars4_074', 'cars4_010', 'cars3_026', 'cars4_085', 'cars063', 'cars4_061', 'cars4_080', 'cars4_128', 'cars4_127', 'cars4_065', 'cars4_037', 'cars060', 'cars4_105', 'cars4_116', 'cars4_124', 'cars2_052', 'cars4_060', 'cars4_005', 'cars056', 'cars4_020', 'cars2_035', 'cars2_032', 'cars4_055', 'cars2_068', 'cars2_042', 'cars4_026', 'cars2_043', 'cars2_073', 'cars4_091', 'cars4_096', 'cars3_017', 'cars2_066', 'cars2_049', 'cars4_108', 'cars4_099', 'cars3_024', 'cars4_081', 'cars2_017', 'cars027', 'cars2_014', 'cars4_114', 'cars4_014', 'cars2_007', 'cars026', 'cars4_117', 'cars3_020', 'cars4_107', 'cars3_019', 'cars061', 'cars4_092', 'cars066', 'cars2_061', 'cars4_054', 'cars2_005', 'cars4_033', 'cars3_011', 'cars036', 'cars4_073', 'cars070', 'cars2_045', 'cars4_015', 'cars4_008', 'cars2_044', 'cars4_083', 'cars032', 'cars065', 'cars040', 'cars4_069', 'cars3_013', 'cars4_109', 'cars2_025', 'cars4_007', 'cars4_129', 'cars2_010', 'cars4_030', 'cars4_097', 'cars3_007', 'cars4_019', 'cars4_048', 'cars4_113', 'cars2_034', 'cars4_039', 'cars3_031', 'cars4_126', 'cars4_131', 'cars4_110', 'cars3_027', 'cars3_021', 'cars4_056', 'cars3_010', 'cars3_009', 'cars4_125', 'cars4_040', 'cars052', 'cars2_012', 'cars4_122', 'cars2_056', 'cars045', 'cars3_008', 'cars4_123', 'cars2_051', 'cars4_088', 'cars058', 'cars2_008', 'cars2_002', 'cars2_016', 'cars4_031', 'cars057', 'cars4_034', 'cars051', 'cars2_046', 'cars4_120', 'cars2_064', 'cars3_001', 'cars4_042', 'cars2_029', 'cars4_072', 'cars4_041', 'cars4_011', 'cars4_036', 'cars2_013', 'cars3_015', 'cars4_104', 'cars069', 'cars2_015', 'cars4_017', 'cars4_103', 'cars2_004', 'cars2_003', 'cars2_027', 'cars4_089', 'cars4_077', 'cars4_112', 'cars4_119', 'cars4_063', 'cars2_069', 'cars2_033', 'cars4_035', 'cars2_026', 'cars2_074', 'cars4_045', 'cars2_006', 'cars2_019', 'cars2_038', 'cars2_072', 'cars2_011', 'cars3_003', 'cars3_014', 'cars4_130', 'cars2_028', 'cars4_057', 'cars031', 'cars4_064', 'cars2_067', 'cars2_037', 'cars3_023', 'cars2_009', 'cars2_024', 'cars4_003', 'cars4_009', 'cars2_036', 'cars055', 'cars2_059', 'cars2_055', 'cars4_111', 'cars067', 'cars2_039', 'cars4_094', 'cars3_022', 'cars2_053', 'cars2_062', 'cars4_024', 'cars4_082', 'cars3_005', 'cars2_054', 'cars2_063', 'cars2_057', 'cars2_065', 'cars4_100', 'cars039', 'cars4_093', 'cars3_030', 'cars3_029', 'cars028', 'cars2_023', 'cars4_029', 'cars053', 'cars4_098', 'cars2_060', 'cars2_050', 'cars4_059', 'cars2_022', 'cars2_058', 'cars4_032', 'cars4_046', 'cars4_086', 'cars3_006', 'cars4_087', 'cars4_006', 'cars2_070', 'cars068', 'cars3_025', 'cars4_101', 'cars029', 'cars2_040', 'cars4_013', 'cars4_022', 'cars4_012', 'cars033', 'cars4_067', 'cars4_025', 'cars3_016', 'cars2_048', 'cars042', 'cars4_018', 'cars2_001', 'cars4_075', 'cars3_012', 'cars2_047', 'cars4_106', 'cars064', 'cars062', 'cars4_047', 'cars4_071', 'cars2_018', 'cars4_102', 'cars4_084', 'cars3_028', 'cars2_020', 'cars2_071', 'cars3_002', 'cars4_078', 'cars3_018', 'cars4_118', 'cars4_016', 'cars2_031', 'cars4_058', 'cars030', 'cars4_079', 'cars3_004', 'cars4_066', 'cars2_041', 'cars4_004', 'cars4_023']
# [STATUS] Original data loaded successfully.

# %%
# initialize path constants
RECOGNITION_DATA_DIR_PATH = sys_path_recognition + "/recognition_data"  # path to modified dataset directory

# create recognition_train.txt - contains paths for images in train data
recognition_train_file = open(RECOGNITION_DATA_DIR_PATH + "/recognition_train.txt", "w+") # open recognition_train.txt in write mode - create if does not exist
for fp in train_data.keys():                                                              # for each file path in train data
    recognition_train_file.write(RECOGNITION_DATA_DIR_PATH + fp + "\n")                      # write the file path to recognition_train.txt on a new line
recognition_train_file.close()                                                            # close recognition_train.txt
print("[STATUS] recognition_train.txt created successfully.")

# create recognition_test.txt - contains paths for images in test data
recognition_test_file = open(RECOGNITION_DATA_DIR_PATH + "/recognition_test.txt", "w+")   # open recognition_test.txt in write mode - create if does not exist
for fp in test_data.keys():                                                               # for each file path in test data
    recognition_test_file.write(RECOGNITION_DATA_DIR_PATH + fp + "\n")                        # write the file path to recognition_test.txt on a new line
recognition_test_file.close()                                                             # close recognition_test.txt
print("[STATUS] recognition_test.txt created successfully.")
# Out:
# [STATUS] recognition_train.txt created successfully.
# [STATUS] recognition_test.txt created successfully.

# %%
# import re (built-in) - multiple delimiters
import re

# initialize path constants
RECOGNITION_LABELS_DIR_PATH = RECOGNITION_DATA_DIR_PATH + "/labels/"   # path to labels directory

# combine original train and test data image labels and file paths
all_data = {}
all_data.update(train_data)
all_data.update(test_data)

# create modified train and test data labels
for fp, label in all_data.items():                                       # for each image
    fn = re.split("/|\.", fp)[2]                                             # split image file path by '/' and '.' delimiters to obtain file name
    label_file = open(RECOGNITION_LABELS_DIR_PATH + fn + ".txt", "w+")       # open image label text file in write mode - create if does not exist
    label_file.write(label)                                                  # write the label to the image label text file
    label_file.close()                                                       # close image label text file

print("[STATUS] Label files for all data created successfully.")
# Out:
# [STATUS] Label files for all data created successfully.

# %% [markdown]
# ### **Data Modification**###
# 1.   Obtain predicted license plate location with YOLOv3 license plate detection model
# 2.   Crop images utilizing YOLOv3 predicted license plate location
#
# Citations for YOLOv3 + OpenCV Image Processing:
# - https://towardsdatascience.com/
# - https://pyimagesearch.com/

# %%
# install dependencies
# !pip install numpy
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.5)

# %%
# relevant file paths
CLASS_NAMES_PATH = sys_path_detection + "/classes.names"
WEIGHTS_PATH = sys_path_detection + "/detection_data/weights/darknet-yolov3-train-custom_final.weights"
YOLO_CFG_PATH = sys_path_detection + "/darknet-yolov3-test-custom.cfg"

# %%
# import dependencies
import numpy as np
import cv2

# load class names files and map class names to a random color
class_names_file = open(CLASS_NAMES_PATH, "r")                              # open class names file
class_names_colors = {}                                                     # dictionary to store class name:class color key:value pairs
for line in class_names_file:                                               # for each class
    class_names_colors[line.strip()] = tuple(np.random.uniform(0, 255, 3))      # assign the class a randomly generated color

# load pre-trained YOLOv3 license plate object detector
net = cv2.dnn.readNetFromDarknet(YOLO_CFG_PATH, WEIGHTS_PATH)

# determine output layers names from YOLO architecture
layer_names = net.getLayerNames()
output_layer_names = [layer_names[i[0]-1] for i in net.getUnconnectedOutLayers()]

print("[STATUS] YOLO model loaded successfully.")
# Out:
# [STATUS] YOLO model loaded successfully.

# %%
# import dependencies
import time

# initialize path constants
ORIG_IMGS_DIR_PATH = LP_NUM_IMG_DATA_DIR_PATH + "/images/"  # path to original dataset images directory

proc_times = []   # list to store all detection processing times for analysis

# crop each image in train and test data
for fn in all_data_fns:                                               # for each image in train data
    curr_img = cv2.imread(ORIG_IMGS_DIR_PATH + fn + ".jpg")               # open the current image
    curr_img_w, curr_img_h = curr_img.shape[1], curr_img.shape[0]         # extract the width and height of the current image

    # execute forward pass of YOLO license plate detector with blob from the current input image
    # obtain bounding boxes, associated probabilities, and processing time
    scale = 1/255.0                                                                       # set the scale
    blob = cv2.dnn.blobFromImage(curr_img, scale, (416, 416), swapRB=True, crop=False)    # create blob from input image
    net.setInput(blob)                                                                    # set input to the network

    start_time = time.time()                                                              # start detection processing timer
    outputs = net.forward(output_layer_names)                                             # get output from the network
    end_time = time.time()                                                                # end detection processing timer
    proc_times.append(end_time - start_time)                                              # calculate detection processing time

    # process results of YOLOv3 model outputs for the current image
    boxes = []                # list to store detected bounding boxes
    confidences = []          # list to store confidences of detected bounding boxes
    class_IDs = []            # list to store class ID of detected bounding boxes
    confidence_thresh = 0.7   # confidence threshold
    nms_thresh = 0.3          # non-maxima suppression threshold

    for output in outputs:                      # for each output
        for detection in output:                    # for each detection in the current output
            scores = detection[5:]                      # obtain the scores for the current detection
            class_ID = np.argmax(scores)                # extract the class ID from the scores
            confidence = scores[class_ID]               # extract the confidence/probability from the scores

            if confidence > confidence_thresh:                  # if confidence of detection is above confidence threshold
                box = detection[0:4] * np.array([curr_img_w, 
                                                curr_img_h, 
                                                curr_img_w, 
                                                curr_img_h])        # scale the bounding box coordinates to current input image size
                cx, cy, w, h = box.astype("int")                    # extract bounding box information => center (x,y) coordinates, width, and height
                tlx, tly = int(cx - (w/2)), int(cy - (h/2))         # compute top-left (x,y) coordinates from center (x,y) coordinates

                boxes.append([tlx, tly, int(w), int(h)])            # update list of detected bounding boxes
                confidences.append(float(confidence))               # update list of confidences
                class_IDs.append(class_ID)                          # update list of class IDs

    # apply non-maxima supprssion (NMS), eliminate weak + overlapping bounding boxes
    idxs = cv2.dnn.NMSBoxes(boxes, confidences, confidence_thresh, nms_thresh)

    # save the current input image (not cropped) with no annotations
    cv2.imwrite(RECOGNITION_DATA_DIR_PATH + "/images_ncropped/" + fn + "_ncropped.jpg", curr_img)

    # annotate detections on current input image
    if len(idxs):                                                                                         # if there is atleast 1 license plate detection
        for i in idxs.flatten():                                                                              # for each kept index
            x, y = boxes[i][0], boxes[i][1]                                                                       # extract bounding box top-left (x,y) coordinates
            w, h = boxes[i][2], boxes[i][3]                                                                       # extract bounding box width and height
            
            # save the current input image cropped to only the license plate
            wbuf = 0   # width cropping buffer to ensure license plate characters are not cut off
            hbuf = 2   # height cropping buffer to ensure license plate characters are not cut off
            curr_img_cropped = curr_img[y-hbuf:y+h+hbuf, x-wbuf:x+w+wbuf]   # crop the current input image to the detected bounding box
            cv2.imwrite(RECOGNITION_DATA_DIR_PATH + "/images_cropped/" + fn + "_cropped.jpg", curr_img_cropped)

            bb_color = list(class_names_colors.values())[class_IDs[i]]                                            # determine color of bounding box for current class
            cv2.rectangle(curr_img, (x,y), (x+w, y+h), bb_color, 2)                                               # draw rectangle on current input image
            text = "{}: {:.4f}".format(list(class_names_colors.keys())[class_IDs[i]], confidences[i])             # set text for bounding box annotation
            cv2.putText(curr_img, text, (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, bb_color, 2)                     # draw text on current input image

    # save the current input image (not cropped) with annotations
    cv2.imwrite(RECOGNITION_DATA_DIR_PATH + "/images_ncropped/" + fn + "_ncropped_ann.jpg", curr_img)

    # print(fn + " processing and cropping completed.")

print("[STATUS] Average Image Detection Processing Time: {} seconds".format(round(sum(proc_times)/len(proc_times), 5)))   # output processing analysis
print("[STATUS] All images in train and test data cropped successfully.")
# Out:
# [STATUS] Average Image Detection Processing Time: 2.5961 seconds
# [STATUS] All images in train and test data cropped successfully.

# %% [markdown]
# ### **Image Processing**###
# 1.   Load Cropped License Plates
# 2.   Resizing
# 3.   Grayscale Conversion
# 4.   Noise Suppression
# 5.   Image Thresholding (Binarization)
# 6.   Image Dilation

# %%
# import dependencies
import cv2
import re

# initialize path constants
CROPPED_IMGS_DIR_PATH = RECOGNITION_DATA_DIR_PATH + "/images_cropped/"    # path to cropped license plate image dataset

# process each image in train and test data
for fn in all_data_fns:  
    curr_img = cv2.imread(CROPPED_IMGS_DIR_PATH + fn +  "_cropped.jpg")  # open current image

    # resize current image to have more pixels/detail
    # no desired size
    # scale width and height by factor of 2
    # bicubic interpolation over 4×4 pixel neighborhood
    resize_curr_img = cv2.resize(curr_img, None, fx=4, fy=4, interpolation = cv2.INTER_CUBIC)

    # apply colorspace conversion to grayscale for image thresholding
    gray_curr_img = cv2.cvtColor(resize_curr_img, cv2.COLOR_BGR2GRAY)
    
    # apply weighted gaussian blur filter - remove image noise
    # 5x5 kernel size - size directly proportional to amount of blur
    # sigma set to 0 - automatically compute sigma based on kernel size
    gauss_curr_img = cv2.GaussianBlur(gray_curr_img, (5, 5), 0)

    # apply image thresholding (binarization - convert all pixels to black or white) 
    # 0 for threshold value - OTSU threshold used instead
    # 255 (white) is new pixel value if current pixel value less than OTSU threshold
    bin_curr_img = cv2.threshold(gauss_curr_img, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

    # apply image dilation to remove image noise after binarization
    # 3x3 kernel size - size directly proportional to amount of dilation
    kernel = np.ones((3, 3), np.uint8)
    dil_curr_img = cv2.dilate(bin_curr_img, kernel) 

    # save the current processed image 
    cv2.imwrite(RECOGNITION_DATA_DIR_PATH + "/images_processed/" + fn + "_processed.jpg", dil_curr_img)

print("[STATUS] All images in train and test data processed successfully.")
# Out:
# [STATUS] All images in train and test data processed successfully.

# %% [markdown]
# ### **Optical Character Recognition (OCR)**###
# 1.   Train Custom OCR Model on License Plate Number Font (Penitentiary Gothic Fill)
# 2.   Input Processed License Plate Images to PyTesseract OCR Engine with Trained Custom OCR Model
# 3.   Evaluate Accuracy of PyTesseract OCR Engine with Trained Custom OCR Model
# 4.   Perform Custom OCR Model Tuning
# 5.   Repeat 1-4

# %%
# install dependencies
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
# import dependencies
import pytesseract
import cv2

# initialize path constants
PROCESSED_IMGS_DIR_PATH = RECOGNITION_DATA_DIR_PATH + "/images_processed/"  # path to cropped license plate image dataset
RECOGNITION_LABELS_DIR_PATH = RECOGNITION_DATA_DIR_PATH + "/labels/"        # path to labels directory

print("Printing Actual | Predicted License Plate Numbers...")

# recognition test over entire dataset
all_data_fns.sort()
for fn in all_data_fns:  
    curr_img = cv2.imread(PROCESSED_IMGS_DIR_PATH + fn + "_processed.jpg")  # open current image
    curr_img_label = open(RECOGNITION_LABELS_DIR_PATH + fn + ".txt").readline()

    options = '--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    curr_img_prediction = pytesseract.image_to_string(curr_img, config=options)

    print("Filename: {} => {} | {}".format(fn, curr_img_label, curr_img_prediction))
# Out:
# Printing Actual | Predicted License Plate Numbers...
# Filename: cars026 => 4YTD483 | LYTHL83I
#
# Filename: cars027 => 5AZJ257 | DAZI257
#
# Filename: cars028 => 5AHH512 | I AMHE 1
#
# Filename: cars029 => 4TAZ530 | FTA25 30:4
#
# Filename: cars030 => 4BYZ014 | PLEYZ91L |
#
# Filename: cars031 => 4MCB318 | LMCB2]P
#
# Filename: cars032 => 5FVL554 | PSF VL 554
#
# Filename: cars033 => 3VBL777 | SUBLI77.
#
# Filename: cars036 => 5AOG200 | SA06200
#
# Filename: cars039 => 1MLN989 | 19].
#
# Filename: cars040 => 6F55687 | 6F55697
#
# Filename: cars042 => 4FJX296 | ! m im S|
#
# Filename: cars045 => 4RFV131 | LLRFV1 31)
#
# Filename: cars051 => 5GRD613 | 'SGRD61 3]
#
# Filename: cars052 => 5EDP688 | I S5EDP 688 |
#
# Filename: cars053 => 3J66282 | 1366282
#
# Filename: cars055 => 4YTN357 | LLYTN35 0,
#
# Filename: cars056 => 4ZTJ876 | L727 J876
#
# Filename: cars057 => 5GGG842 | a SGGGRL.
#
# Filename: cars058 => 4ZNS935 | 1.2NS935]
#
# Filename: cars060 => 5HCV316 | SHCV316.
#
# Filename: cars061 => 6K75488 | 6K 75L89
#
# Filename: cars062 => CKC3951 | THAN
#
# Filename: cars063 => 5DHU058 | SDHU058
#
# Filename: cars064 => 4BTP882 | 1 |
#
# Filename: cars065 => 4KYR003 | Warde
#
# Filename: cars066 => 5JUU305 | 15 JUU305)
#
# Filename: cars067 => 4RLX774 | URLX774
#
# Filename: cars068 => 4TDS709 | ALTDS709,.
#
# Filename: cars069 => 5HAY956 | BINGE
#
# Filename: cars070 => 4KRH440 | LLY |
#
# Filename: cars2_001 => 3NBU698 | A SNBUSISI
#
# Filename: cars2_002 => 4URR806 | | LURRSOS |
#
# Filename: cars2_003 => 3VMT947 | QWMTILT
#
# Filename: cars2_004 => 4XEK968 | LYEKI68
#
# Filename: cars2_005 => 2ZMF731 | 7A33L74
#
# Filename: cars2_006 => 4RAR512 |
# Filename: cars2_007 => 4GJB914 | LGJBI1L
#
# Filename: cars2_008 => 3UMH807 | AMHBO |
#
# Filename: cars2_009 => 3GXA280 | 1 3GXA280'
#
# Filename: cars2_010 => 5AFD170 | SAEDITO |
#
# Filename: cars2_011 => 4SYK188 | LSYK188
#
# Filename: cars2_012 => 4UET042 |
# Filename: cars2_013 => 4UQD589 | MN er ee 9)
#
# Filename: cars2_014 => 4YNT983 | LYNT983
#
# Filename: cars2_015 => 2SWT841 | SWI 8L I
#
# Filename: cars2_016 => 3LRH261 | 31 RH261
#
# Filename: cars2_017 => 3KGD519 | 2xKCN519
#
# Filename: cars2_018 => 4MEU123 | i LMEWL2 3]
#
# Filename: cars2_019 => 4WAG411 | LWAGLLL,
#
# Filename: cars2_020 => 4MTV159 | LMT V159.
#
# Filename: cars2_021 => 3MYH761 | QMVHT 61
#
# Filename: cars2_022 => 4NFU116 | ENEUL LG!
#
# Filename: cars2_023 => 4NSJ648 | INS S648
#
# Filename: cars2_024 => 3GPD173 | I 3¢PDL13
#
# Filename: cars2_025 => 4YNE038 | | LYNED38.
#
# Filename: cars2_026 => 5AKL759 |
# Filename: cars2_027 => 3SKC930 | B2sK09 3
#
# Filename: cars2_028 => 3VOM582 | 304582)
#
# Filename: cars2_029 => 3PXM126 | 1Py
# M128
# rg
#
# Filename: cars2_031 => 4RWR022 | AL RWROZ/|
#
# Filename: cars2_032 => 4VAH764 | LVAHT6L.
#
# Filename: cars2_033 => 5DES024 | ISDESOZ4
#
# Filename: cars2_034 => 5N30048 | 5N30048,
#
# Filename: cars2_035 => 2VLR763 | |2VLRT63|
#
# Filename: cars2_036 => 6A14467 | LN 67
#
# Filename: cars2_037 => 4ZOW567 |
# Filename: cars2_038 => 4S45794 | 1.545794)
#
# Filename: cars2_039 => 5H49444 | SUL OL LL |
#
# Filename: cars2_040 => 4HPV976 | LPO 16
#
# Filename: cars2_041 => 4NIU770 |
# Filename: cars2_042 => 4VLX070 | 1LVLXO7TO)
#
# Filename: cars2_043 => 3VDM690 | °WM690
#
# Filename: cars2_044 => 6M28575 | 6M28575|
#
# Filename: cars2_045 => ONEOFME | MIG Pa
#
# Filename: cars2_046 => VGREWAL | A\GREWAL
#
# Filename: cars2_047 => 3RLT669 | $301 16691
#
# Filename: cars2_048 => 4HMS824 |
# Filename: cars2_049 => 5FZH911 |
# Filename: cars2_050 => 3UOA792 | 3K 7921
#
# Filename: cars2_051 => 4YKX864 | LYK KSeL|
#
# Filename: cars2_052 => 4UCF349 | LUCK 3L9 |
#
# Filename: cars2_053 => 3NFZ068 | BNF 7048)
#
# Filename: cars2_054 => 4CSD123 | LCSD123
#
# Filename: cars2_055 => 2ZMF731 | a7KF 13))
#
# Filename: cars2_056 => 4WKZ117 | EWKZLLT
#
# Filename: cars2_057 => 5AUX641 | SAUK GLI
#
# Filename: cars2_058 => 1TM115 | ieee
#
# Filename: cars2_059 => 4NUR417 | BNURGLT E
#
# Filename: cars2_060 => 4PZC313 | 4P20313
#
# Filename: cars2_061 => 3HMC645 | IHMC ELE
#
# Filename: cars2_062 => 5GWT825 | 5GW1825
#
# Filename: cars2_063 => 5GRV545 | B5GRV5L5|
#
# Filename: cars2_064 => 4HKV326 | HK 326
#
# Filename: cars2_065 => 4ZBH748 | 1 7RHTLB
#
# Filename: cars2_066 => 4MBS696 | A MBS69GT
#
# Filename: cars2_067 => 4AIP382 | WLATP382
#
# Filename: cars2_068 => 4TIX783 |
# Filename: cars2_069 => 4KEE446 | LKEELLS
#
# Filename: cars2_070 => 4RYG474 | TRYIVATA
#
# Filename: cars2_071 => 4FSK683 | LE SK 683 |
#
# Filename: cars2_072 => 3TEA385 | | IT EA3B5 |
#
# Filename: cars2_073 => 5JBR554 | 5 JBROSL
#
# Filename: cars2_074 => 4PPR267 | 4.PPR26UR
#
# Filename: cars3_001 => 2WWL293 | Wut 29
#
# Filename: cars3_002 => 4JPA838 | Ay IPARIBI
#
# Filename: cars3_003 => 4VCR183 | LVCRL83
#
# Filename: cars3_004 => 3JYT812 | 3 YTS)
#
# Filename: cars3_005 => 4LME807 | LLL. MESOT"
#
# Filename: cars3_006 => 4YUJ904 | LYUS9OL,
#
# Filename: cars3_007 => 5DJZ952 | 5D Z9a2
#
# Filename: cars3_008 => 4LZW133 | LI ZWL32
#
# Filename: cars3_009 => 4UPV426 | LUPVL26
#
# Filename: cars3_010 => 2XAX069 | 2XAX069
#
# Filename: cars3_011 => 4AYK317 | LAYK 317
#
# Filename: cars3_012 => 4WMC477 | a WMCUT I
#
# Filename: cars3_013 => 4YZU576 | LYZU5T6
#
# Filename: cars3_014 => 5W64177 | WG L LT
#
# Filename: cars3_015 => 2BKP112 | iS RK Pil Cad
#
# Filename: cars3_016 => 4VUG504 | IL. VUG5O4|
#
# Filename: cars3_017 => 4EZH622 | | LEZH622
#
# Filename: cars3_018 => 3SAV178 |
# Filename: cars3_019 => 4YUF560 | I YUFS60}
#
# Filename: cars3_020 => 5CQU569 | mr QUSEI
#
# Filename: cars3_021 => 5EQF286 |
# Filename: cars3_022 => 3CBM414 | H3CBML IL |
#
# Filename: cars3_023 => 3HWL391 |
# Filename: cars3_024 => 4HGT934 | BLLHGT934
#
# Filename: cars3_025 => 2ZJG389 | 27 JG389
#
# Filename: cars3_026 => 4GQG231 | 1.606231
#
# Filename: cars3_027 => 4RXJ811 |
# Filename: cars3_028 => 4PBZ953 | LPBZ2952
#
# Filename: cars3_029 => 2GMZ940 | VCMZ9L0
#
# Filename: cars3_030 => 4HHZ338 |  LHHZ 338
#
# Filename: cars3_031 => 5BPJ707 | \5RPJT07
#
# Filename: cars4_003 => 4HAT861 | HLHATS6LI
#
# Filename: cars4_004 => 4EMJ817 | Na ee
#
# Filename: cars4_005 => 3UXY336 | 3UXY336
#
# Filename: cars4_006 => 5CGP522 | = eel elU Chl
# oe, =
# 7
# OE OD lee oe, CC
#
# Filename: cars4_007 => 4ROW485 |
# Filename: cars4_008 => 4BMZ563 | .BMZ563
#
# Filename: cars4_009 => 4CKX724 | LCKX 726
#
# Filename: cars4_010 => 5CJB364 | BS CIB36LM
#
# Filename: cars4_011 => 4XNG329 | BLYNG3294
#
# Filename: cars4_012 => 5CLE992 | BCLE992°
#
# Filename: cars4_013 => 4MXW451 |
# Filename: cars4_014 => 4DRP153 | 4] Bg 3
# LDI P153
#
# Filename: cars4_015 => 4ZWZ399 | I ~~ A
#
# Filename: cars4_016 => 018VFJ | og 0N
#
# Filename: cars4_017 => 3VZJ707 | 3V2J707.
#
# Filename: cars4_018 => 4VWL023 | LV 023 |
#
# Filename: cars4_019 => 5JMZ542 | 15 JMZ5L2
#
# Filename: cars4_020 => MADZBMR | | MADZBMR
#
# Filename: cars4_022 => 4PZN989 | FLPZN989 |
#
# Filename: cars4_023 => 4NSJ053 | | LNS.1053 |
#
# Filename: cars4_024 => 3LYF124 | PLYFL2ZUh
#
# Filename: cars4_025 => HLPUBU | PHLP UBU
#
# Filename: cars4_026 => 6J01992 |
# Filename: cars4_029 => 4TTP179 | LTTP179)
#
# Filename: cars4_030 => 7J15194 | NT IISI9LN
#
# Filename: cars4_031 => 3LUD179 | ILUDLT IN
#
# Filename: cars4_032 => 4FJX849 | PLE XSL 9]
#
# Filename: cars4_033 => 4RZD675 | 14RZ0675|
#
# Filename: cars4_034 => 5CEV521 | BCEY521
#
# Filename: cars4_035 => 5EBU328 | SEBU328
#
# Filename: cars4_036 => 4XTJ589 |
# Filename: cars4_037 => 4LXC614 | LI X06) b
#
# Filename: cars4_039 => 2TVZ312 | 21V7312
#
# Filename: cars4_040 => 4FWH626 | HF WH626|
#
# Filename: cars4_041 => 5JFY719 | BS JFY7191
#
# Filename: cars4_042 => 5JFY719 | Sarvs
#
# Filename: cars4_045 => 5FVW911 | SFVWOL)
#
# Filename: cars4_046 => 4DSP764 | BLDSP 764!
#
# Filename: cars4_047 => 2SQH590 | B2S0H590 |
#
# Filename: cars4_048 => 4RIM152 | 9) GRIM152'§
#
# Filename: cars4_052 => 3UDX841 | [3UDX841]
#
# Filename: cars4_054 => 4WOU744 | mL WOUTLL
#
# Filename: cars4_055 => 3UTA977 | g pS Bie 7|
#
# Filename: cars4_056 => 5BQE919 | a 5B0E919 |
#
# Filename: cars4_057 => 5FDJ896 | | 5FDJ896 |
#
# Filename: cars4_058 => 5DES551 | ISDES551|
#
# Filename: cars4_059 => 281SGL | 281-S6L
#
# Filename: cars4_060 => 5ETA743 | BETATL3
#
# Filename: cars4_061 => 4BRM434 | IL BRML, 34 |
#
# Filename: cars4_063 => 2YCG276 | 12 YCG276)
#
# Filename: cars4_064 => 5CWJ628 | BC hed 3
#
# Filename: cars4_065 => 3SFW623 | | 3SFHS23
#
# Filename: cars4_066 => 4TXY019 | Py 7d
#
# Filename: cars4_067 => 3WVM533 | ents:
#
# Filename: cars4_069 => 5DXZ250 | 15D
# DxZZ5°]
#
# Filename: cars4_071 => 3GWK394 | IGHK 394
#
# Filename: cars4_072 => 2SQH590 | Th
# AGI
# \OH
# 1°
#
# Filename: cars4_073 => 4DSP764 | -“-_-e *
# - -
#
# _
#
# —~ ~~ ~~
#
# Filename: cars4_074 => 5HZW063 | one
#
# Filename: cars4_075 => 4AST141 | SLASTIOL
#
# Filename: cars4_077 => 4XDV653 | 4XDV653
#
# Filename: cars4_078 => 3SLS141 | B25. Sth
#
# Filename: cars4_079 => AHA6497 | | AHA-64-97
#
# Filename: cars4_080 => 4CBM944 | ILC EWSL 1 |
#
# Filename: cars4_081 => 5EFR764 | SEFRTGL
#
# Filename: cars4_082 => 7J96298 | 17 J9Z298
#
# Filename: cars4_083 => 1408S | BTR 08S
#
# Filename: cars4_084 => 3VBM338 |
# Filename: cars4_085 => 2PXR727 | 2PXRT27
#
# Filename: cars4_086 => 3RMX731 | I 3RMY 731
#
# Filename: cars4_087 => 4GNU890 | LGNU890
#
# Filename: cars4_088 => 4COV126 |
# Filename: cars4_089 => 4KSU403 | LK SULO3
#
# Filename: cars4_091 => 4LMC535 | LL MC5 35
#
# Filename: cars4_092 => 4RHM244 | LRHM2/.
#
# Filename: cars4_093 => 4DLS556 | 1L4DLS556
#
# Filename: cars4_094 => 3GPC664 | N3CPC6GL
#
# Filename: cars4_096 => 5EMR875 | BSEMRO75
#
# Filename: cars4_097 => 4YHY530 | LYHY530
#
# Filename: cars4_098 => 5GRL983 |
# Filename: cars4_099 => 3LVH137 |
# Filename: cars4_100 => 4PRU547 | LPRU5L 7
#
# Filename: cars4_101 => 2T0G518 | #2706518 |
#
# Filename: cars4_102 => RNM25X | IRNM25X
#
# Filename: cars4_103 => 5AQR840 | SAQRBLO
#
# Filename: cars4_104 => 5DRM137 | 1 5DRM137 |
#
# Filename: cars4_105 => 5GEC237 | 5GEC237
#
# Filename: cars4_106 => 4ZPG408 |
# Filename: cars4_107 => 3LUK250 | DISS, Ng
#
# Filename: cars4_108 => 3DGL956 | 13DGL956|
#
# Filename: cars4_109 => MARETA |
# Filename: cars4_110 => 4GNE041 | LGNEOL1
#
# Filename: cars4_111 => 2LIN692 | 2. 1N692
#
# Filename: cars4_112 => 4ZNN507 | /4ZNN507
#
# Filename: cars4_113 => 4SFK926 | LSFK92¢
#
# Filename: cars4_114 => 4JKA394 | BL IKAI9LN
#
# Filename: cars4_116 => 3UUJ586 | BUN I5865
#
# Filename: cars4_117 => 4JRV393 | LJRV397
#
# Filename: cars4_118 => 3TKA605 |
# Filename: cars4_119 => 4WAG376 | VLWAG376I
#
# Filename: cars4_120 => 4LLU860 | ULLUB6O
#
# Filename: cars4_122 => 4JPY855 | BL IPYSSS |
#
# Filename: cars4_123 => JSR113 | SR 1130
#
# Filename: cars4_124 => 5GAM144 | SGAMILL
#
# Filename: cars4_125 => 4TZB662 | LTZB662
#
# Filename: cars4_126 => 5GEF645 | BSCE 6L5 |
#
# Filename: cars4_127 => 5BSM366 | ES BSM366|
#
# Filename: cars4_128 => 5JJV943 | BS JJV9L3]
#
# Filename: cars4_129 => 4FVV176 |
# Filename: cars4_130 => 5BKV051 | SBKVOSL
#
# Filename: cars4_131 => 4GTA922 | LAGTA9224
